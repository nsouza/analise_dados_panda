# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'A': ['verdadeiro', 'falso', 'verdadeiro', 'falso','verdadeiro', 'falso', 'verdadeiro', 'falso'],
    'B': ['um', 'um', 'dois', 'tres','dois', 'dois', 'um', 'tres'],
    'C': np.random.randn(8),
    'D': np.random.randn(8)
})

# %%
df
# Out:
#             A     B         C         D
# 0  verdadeiro    um  1.623758  0.105743
# 1       falso    um  0.744694  1.054625
# 2  verdadeiro  dois -1.266522  0.570905
# 3       falso  tres  0.837114 -1.005482
# 4  verdadeiro  dois -0.328745  0.142890
# 5       falso  dois  1.056957 -1.181310
# 6  verdadeiro    um -0.789801  1.389818
# 7       falso  tres -1.717284  2.265766

# %%
df.groupby(['A']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Público/Curso/analise_pandas/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File ~/Público/Curso/analise_pandas/.venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Público/Curso/analise_pandas/.venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
df.groupby('B')[['C','D']].mean()
# Out:
#              C         D
# B
# dois -0.179437 -0.155839
# tres -0.440085  0.630142
# um    0.526217  0.850062

# %%
#Agrupara varias colunas
df.groupby(['A','B'])[['C','D']].mean()
# Out:
#                         C         D
# A          B
# falso      dois  1.056957 -1.181310
#            tres -0.440085  0.630142
#            um    0.744694  1.054625
# verdadeiro dois -0.797633  0.356897
#            um    0.416978  0.747780
