# %%
import matplotlib.pyplot as plt 
import numpy as np 

plt.style.use('ggplot')

# %%
np.random.seed(seed=0)

x = np.random.randn(1000)
y = np.random.randn(100)
z = np.random.randn(10)

# %%
fig, ax = plt.subplots()

#Se vert=True os blocos ficam na posição vertial
ax.boxplot((x, y, z), vert=False, showmeans=True, meanline=True,
           labels=('x','y','z'), patch_artist=True,
           medianprops={'linewidth': 2, 'color': 'purple'},
           meanprops={'linewidth': 2, 'color': 'purple'})

plt.savefig('nome_fig.png')
plt.show()
# Out:
# /tmp/ipykernel_63186/2702742723.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot((x, y, z), vert=False, showmeans=True, meanline=True,
