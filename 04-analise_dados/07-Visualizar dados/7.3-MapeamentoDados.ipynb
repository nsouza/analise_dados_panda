# %%
import pandas as pd

# %%
#criando um dataframa com dados categorios
data = {'cor':['vermelho','azul','verde','azul','vermelho']}
df = pd.DataFrame(data)

# %%
df['cor'].unique()
# Out:
# array(['vermelho', 'azul', 'verde'], dtype=object)

# %%
#mapa de cores
mapa = {'vermelho':1, 'verde':2, 'azul':3}

# %%
df['cor_numero'] = df['cor'].map(mapa)

# %%
df
# Out:
#         cor  cor_numero
# 0  vermelho           1
# 1      azul           3
# 2     verde           2
# 3      azul           3
# 4  vermelho           1
